# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns
from tensorflow.keras.layers import Dense

# %%
X,y=make_circles(n_samples=100,noise=0.1,random_state=1)

# %%
sns.scatterplot(X[:,0],X[:,1],hue=y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-3dbc6f4a86c6> in <cell line: 1>()
# ----> 1 sns.scatterplot(X[:,0],X[:,1],hue=y)
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.2, random_state=2)

# %%
model=Sequential()
model.add(Dense(256,input_dim=2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=3500,verbose=0)

# %%
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test,y_test.ravel(),clf=model,legend=2)
# Out:
# 9600/9600 [==============================] - 14s 1ms/step
# <Axes: >

# %% [markdown]
# **Early Stopping**

# %%
model=Sequential()
model.add(Dense(256,input_dim=2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
callback=EarlyStopping(
    monitor="val_loss",
    min_delta=0.0001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=3500,verbose=1,callbacks=callback)
# Out:
# Epoch 1/3500
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6777 - accuracy: 0.5625 - val_loss: 0.7167 - val_accuracy: 0.4000
# Epoch 2/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6773 - accuracy: 0.5625 - val_loss: 0.7158 - val_accuracy: 0.4000
# Epoch 3/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6765 - accuracy: 0.5625 - val_loss: 0.7160 - val_accuracy: 0.4000
# Epoch 4/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6759 - accuracy: 0.5750 - val_loss: 0.7161 - val_accuracy: 0.4000
# Epoch 5/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6753 - accuracy: 0.5875 - val_loss: 0.7167 - val_accuracy: 0.4000
# Epoch 6/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6747 - accuracy: 0.5875 - val_loss: 0.7165 - val_accuracy: 0.4000
# Epoch 7/3500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6742 - accuracy: 0.5750 - val_loss: 0.7167 - val_accuracy: 0.4000
# Epoch 8/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6735 - accuracy: 0.5750 - val_loss: 0.7169 - val_accuracy: 0.4000
# Epoch 9/3500
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6731 - accuracy: 0.5875 - val_loss: 0.7175 - val_accuracy: 0.4000
# Epoch 10/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6723 - accuracy: 0.5875 - val_loss: 0.7176 - val_accuracy: 0.4000
# Epoch 11/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6719 - accuracy: 0.5875 - val_loss: 0.7175 - val_accuracy: 0.4000
# Epoch 12/3500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6711 - accuracy: 0.5875 - val_loss: 0.7182 - val_accuracy: 0.4000
# Epoch 13/3500
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6707 - accuracy: 0.5875 - val_loss: 0.7192 - val_accuracy: 0.4000
# Epoch 14/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6702 - accuracy: 0.5875 - val_loss: 0.7201 - val_accuracy: 0.4000
# Epoch 15/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6699 - accuracy: 0.5875 - val_loss: 0.7197 - val_accuracy: 0.4000
# Epoch 16/3500
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6686 - accuracy: 0.5875 - val_loss: 0.7205 - val_accuracy: 0.4000
# Epoch 17/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6682 - accuracy: 0.5750 - val_loss: 0.7219 - val_accuracy: 0.4000
# Epoch 18/3500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6674 - accuracy: 0.5750 - val_loss: 0.7223 - val_accuracy: 0.4000
# Epoch 19/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6670 - accuracy: 0.5625 - val_loss: 0.7223 - val_accuracy: 0.4000
# Epoch 20/3500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6671 - accuracy: 0.5625 - val_loss: 0.7227 - val_accuracy: 0.3500
# Epoch 21/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6655 - accuracy: 0.5750 - val_loss: 0.7229 - val_accuracy: 0.4000
# Epoch 22/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6650 - accuracy: 0.5750 - val_loss: 0.7234 - val_accuracy: 0.4000
# Epoch 22: early stopping

# %%
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test,y_test.ravel(),clf=model,legend=2)
# Out:
# 9600/9600 [==============================] - 14s 1ms/step
# <Axes: >
