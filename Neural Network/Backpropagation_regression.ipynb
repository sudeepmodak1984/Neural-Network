# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]],columns=['cgpa','profile_score','lpa'])

# %%
df
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['cgpa'].plot(kind='hist', bins=20, title='cgpa')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['profile_score'].plot(kind='hist', bins=20, title='profile_score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['lpa'].plot(kind='hist', bins=20, title='lpa')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='cgpa', y='profile_score', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='profile_score', y='lpa', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['profile_score']
#   ys = series['cgpa']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('profile_score', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('profile_score')
# _ = plt.ylabel('cgpa')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['profile_score']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'profile_score'}, axis=1)
#               .sort_values('profile_score', ascending=True))
#   xs = counted['profile_score']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('profile_score', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('profile_score')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['lpa']
#   ys = series['cgpa']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('lpa', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('lpa')
# _ = plt.ylabel('cgpa')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['lpa']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'lpa'}, axis=1)
#               .sort_values('lpa', ascending=True))
#   xs = counted['lpa']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('lpa', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('lpa')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['cgpa'].plot(kind='line', figsize=(8, 4), title='cgpa')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['profile_score'].plot(kind='line', figsize=(8, 4), title='profile_score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['lpa'].plot(kind='line', figsize=(8, 4), title='lpa')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
def initialize_parameters(layer_dims):

  np.random.seed(3)
  parameters = {}
  L = len(layer_dims)

  for l in range(1, L):

    parameters['W' + str(l)] = np.ones((layer_dims[l-1], layer_dims[l]))*0.1
    parameters['b' + str(l)] = np.zeros((layer_dims[l], 1))


  return parameters

# %%
initialize_parameters([2,2,1])
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
def linear_forward(A_prev, W, b):

  Z = np.dot(W.T, A_prev) + b

  return Z

# %%
# Forward Prop
def L_layer_forward(X, parameters):

  A = X
  L = len(parameters) // 2                  # number of layers in the neural network

  for l in range(1, L+1):
    A_prev = A
    Wl = parameters['W' + str(l)]
    bl = parameters['b' + str(l)]
    #print("A"+str(l-1)+": ", A_prev)
    #print("W"+str(l)+": ", Wl)
    #print("b"+str(l)+": ", bl)
    #print("--"*20)

    A = linear_forward(A_prev, Wl, bl)
    #print("A"+str(l)+": ", A)
    #print("**"*20)

  return A,A_prev

# %%
X = df[['cgpa', 'profile_score']].values[0].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['lpa']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat,A1 = L_layer_forward(X, parameters)

# %%
update_parameters(parameters,y,y_hat,A1,X)

# %%
def update_parameters(parameters,y,y_hat,A1,X):
  parameters['W2'][0][0] = parameters['W2'][0][0] + (0.001 * 2 * (y - y_hat)*A1[0][0])
  parameters['W2'][1][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat)*A1[1][0])
  parameters['b2'][0][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat))

  parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[0][0])
  parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[1][0])
  parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0])

  parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[0][0])
  parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[1][0])
  parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0])

# %%
X = df[['cgpa', 'profile_score']].values[0].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['lpa']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat,A1 = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

parameters
# Out:
# {'W1': array([[0.10658137, 0.10658137],
#         [0.10658137, 0.10658137]]),
#  'b1': array([[0.00082267],
#         [0.00082267]]),
#  'W2': array([[0.111776],
#         [0.111776]]),
#  'b2': array([[0.119136]])}

# %%
X = df[['cgpa', 'profile_score']].values[0].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['lpa']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat,A1 = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

parameters
# Out:
# {'W1': array([[0.10658137, 0.10658137],
#         [0.10658137, 0.10658137]]),
#  'b1': array([[0.00082267],
#         [0.00082267]]),
#  'W2': array([[0.111776],
#         [0.111776]]),
#  'b2': array([[0.119136]])}

# %% [markdown]
# **Using Keras Library**

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(2,activation='linear',input_dim=2))
model.add(Dense(1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[-0.26090986, -0.24798262],
#         [ 0.3125676 , -0.86285293]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-0.12771308],
#         [-0.04679012]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
new_weights=[np.array([[0.1,0.1],[0.1,0.1]],dtype=np.float32),np.array([0.,0.],dtype=np.float32),np.array([[0.1],[0.1]],dtype=np.float32),np.array([0.],dtype=np.float32)]

# %%
model.set_weights(new_weights)

# %%
model.get_weights()
# Out:
# [array([[0.1, 0.1],
#         [0.1, 0.1]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.1],
#         [0.1]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
optimizer=keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mean_squared_error',optimizer=optimizer)

# %%
model.fit(df.iloc[:,0:-1].values,df['lpa'].values,epochs=75,verbose=1,batch_size=1)
# Out:
# Epoch 1/75
# 4/4 [==============================] - 1s 9ms/step - loss: 27.9132
# Epoch 2/75
# 4/4 [==============================] - 0s 6ms/step - loss: 27.5625
# Epoch 3/75
# 4/4 [==============================] - 0s 4ms/step - loss: 27.2643
# Epoch 4/75
# 4/4 [==============================] - 0s 5ms/step - loss: 26.9363
# Epoch 5/75
# 4/4 [==============================] - 0s 4ms/step - loss: 26.5711
# Epoch 6/75
# 4/4 [==============================] - 0s 4ms/step - loss: 26.1927
# Epoch 7/75
# 4/4 [==============================] - 0s 5ms/step - loss: 25.8424
# Epoch 8/75
# 4/4 [==============================] - 0s 4ms/step - loss: 25.4570
# Epoch 9/75
# 4/4 [==============================] - 0s 4ms/step - loss: 25.0648
# Epoch 10/75
# 4/4 [==============================] - 0s 5ms/step - loss: 24.6712
# Epoch 11/75
# 4/4 [==============================] - 0s 4ms/step - loss: 24.2519
# Epoch 12/75
# 4/4 [==============================] - 0s 6ms/step - loss: 23.8512
# Epoch 13/75
# 4/4 [==============================] - 0s 7ms/step - loss: 23.3798
# Epoch 14/75
# 4/4 [==============================] - 0s 5ms/step - loss: 22.9482
# Epoch 15/75
# 4/4 [==============================] - 0s 7ms/step - loss: 22.5155
# Epoch 16/75
# 4/4 [==============================] - 0s 6ms/step - loss: 22.0348
# Epoch 17/75
# 4/4 [==============================] - 0s 6ms/step - loss: 21.5251
# Epoch 18/75
# 4/4 [==============================] - 0s 4ms/step - loss: 21.0939
# Epoch 19/75
# 4/4 [==============================] - 0s 8ms/step - loss: 20.6065
# Epoch 20/75
# 4/4 [==============================] - 0s 5ms/step - loss: 20.1062
# Epoch 21/75
# 4/4 [==============================] - 0s 6ms/step - loss: 19.5490
# Epoch 22/75
# 4/4 [==============================] - 0s 12ms/step - loss: 19.0627
# Epoch 23/75
# 4/4 [==============================] - 0s 14ms/step - loss: 18.5761
# Epoch 24/75
# 4/4 [==============================] - 0s 12ms/step - loss: 18.0763
# Epoch 25/75
# 4/4 [==============================] - 0s 12ms/step - loss: 17.5256
# Epoch 26/75
# 4/4 [==============================] - 0s 12ms/step - loss: 16.9835
# Epoch 27/75
# 4/4 [==============================] - 0s 13ms/step - loss: 16.4473
# Epoch 28/75
# 4/4 [==============================] - 0s 8ms/step - loss: 15.9536
# Epoch 29/75
# 4/4 [==============================] - 0s 4ms/step - loss: 15.4132
# Epoch 30/75
# 4/4 [==============================] - 0s 4ms/step - loss: 14.9059
# Epoch 31/75
# 4/4 [==============================] - 0s 3ms/step - loss: 14.3951
# Epoch 32/75
# 4/4 [==============================] - 0s 4ms/step - loss: 13.8234
# Epoch 33/75
# 4/4 [==============================] - 0s 4ms/step - loss: 13.3290
# Epoch 34/75
# 4/4 [==============================] - 0s 3ms/step - loss: 12.8641
# Epoch 35/75
# 4/4 [==============================] - 0s 3ms/step - loss: 12.3431
# Epoch 36/75
# 4/4 [==============================] - 0s 4ms/step - loss: 11.7902
# Epoch 37/75
# 4/4 [==============================] - 0s 4ms/step - loss: 11.3305
# Epoch 38/75
# 4/4 [==============================] - 0s 4ms/step - loss: 10.8075
# Epoch 39/75
# 4/4 [==============================] - 0s 3ms/step - loss: 10.3380
# Epoch 40/75
# 4/4 [==============================] - 0s 3ms/step - loss: 9.9183
# Epoch 41/75
# 4/4 [==============================] - 0s 5ms/step - loss: 9.4416
# Epoch 42/75
# 4/4 [==============================] - 0s 3ms/step - loss: 9.0090
# Epoch 43/75
# 4/4 [==============================] - 0s 4ms/step - loss: 8.5652
# Epoch 44/75
# 4/4 [==============================] - 0s 4ms/step - loss: 8.0899
# Epoch 45/75
# 4/4 [==============================] - 0s 4ms/step - loss: 7.7474
# Epoch 46/75
# 4/4 [==============================] - 0s 5ms/step - loss: 7.2666
# Epoch 47/75
# 4/4 [==============================] - 0s 4ms/step - loss: 6.9223
# Epoch 48/75
# 4/4 [==============================] - 0s 4ms/step - loss: 6.5592
# Epoch 49/75
# 4/4 [==============================] - 0s 3ms/step - loss: 6.2011
# Epoch 50/75
# 4/4 [==============================] - 0s 5ms/step - loss: 5.8996
# Epoch 51/75
# 4/4 [==============================] - 0s 4ms/step - loss: 5.5008
# Epoch 52/75
# 4/4 [==============================] - 0s 3ms/step - loss: 5.1761
# Epoch 53/75
# 4/4 [==============================] - 0s 4ms/step - loss: 4.9243
# Epoch 54/75
# 4/4 [==============================] - 0s 4ms/step - loss: 4.6208
# Epoch 55/75
# 4/4 [==============================] - 0s 4ms/step - loss: 4.3602
# Epoch 56/75
# 4/4 [==============================] - 0s 4ms/step - loss: 4.1243
# Epoch 57/75
# 4/4 [==============================] - 0s 4ms/step - loss: 3.8813
# Epoch 58/75
# 4/4 [==============================] - 0s 5ms/step - loss: 3.6104
# Epoch 59/75
# 4/4 [==============================] - 0s 4ms/step - loss: 3.4096
# Epoch 60/75
# 4/4 [==============================] - 0s 4ms/step - loss: 3.2479
# Epoch 61/75
# 4/4 [==============================] - 0s 4ms/step - loss: 3.0561
# Epoch 62/75
# 4/4 [==============================] - 0s 4ms/step - loss: 2.8169
# Epoch 63/75
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6660
# Epoch 64/75
# 4/4 [==============================] - 0s 5ms/step - loss: 2.5783
# Epoch 65/75
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4040
# Epoch 66/75
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2622
# Epoch 67/75
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1459
# Epoch 68/75
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0614
# Epoch 69/75
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9427
# Epoch 70/75
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8388
# Epoch 71/75
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7785
# Epoch 72/75
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6751
# Epoch 73/75
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6327
# Epoch 74/75
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5420
# Epoch 75/75
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4885
